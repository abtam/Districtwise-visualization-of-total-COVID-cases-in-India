# %%
import pandas as pd

# %%
cvd_data=pd.read_excel('Cumulative COVID Data.xlsx')

# %%
cvd_data
# Out:
#               State        District  2020-01-30 00:00:00  2020-01-31 00:00:00  \
# 0    Andhra Pradesh  Andhra Pradesh                    0                    0
# 1    Andhra Pradesh       Anantapur                    0                    0
# 2    Andhra Pradesh        Chittoor                    0                    0
# 3    Andhra Pradesh   East Godavari                    0                    0
# 4    Andhra Pradesh          Guntur                    0                    0
# ..              ...             ...                  ...                  ...
# 803      Puducherry        Karaikal                    0                    0
# 804      Puducherry           Mah̩                    0                    0
# 805      Puducherry     Pondicherry                    0                    0
# 806      Puducherry           Yanam                    0                    0
# 807      Puducherry         Unknown                    0                    0
#
# ...

# %%
states=cvd_data[cvd_data['State']==cvd_data['District']]

# %%
states
# Out:
#                                         State  \
# 0                              Andhra Pradesh
# 15                          Arunachal Pradesh
# 42                                      Assam
# 77                                      Bihar
# 117                               Chattisgarh
# 147                                       Goa
# 151                                   Gujarat
# 186                                   Haryana
# 210                          Himachal Pradesh
# 224                                 Jharkhand
# 250                                 Karnataka
# 282                                    Kerala
# 298                            Madhya Pradesh
# 355                               Maharashtra
# 393                                   Manipur
# 411                                 Meghalaya
# 424                                   Mizoram
# 434                                  Nagaland
# 448                                    Odisha
# ...

# %%
states.drop(index=752,inplace=True)
# Out:
# c:\users\abhijeet\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
states.drop(index=786,inplace=True)

# %%
states.index
# Out:
# Int64Index([  0,  15,  42,  77, 117, 147, 151, 186, 210, 224, 250, 282, 298,
#             355, 393, 411, 424, 434, 448, 480, 504, 539, 545, 585, 620, 630,
#             707, 722, 747, 753, 755, 760, 782, 787, 789, 802],
#            dtype='int64')

# %%
cvd_data.drop(index=states.index,inplace=True)

# %%
unk_dist= cvd_data[cvd_data['District']=='Unknown']

# %%
cvd_data.drop(index=unk_dist.index,inplace=True)

# %%
cvd_data.to_excel('Cleaned COVID Cumulative Cases.xlsx')
